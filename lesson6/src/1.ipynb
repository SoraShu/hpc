# %%
import pandas as pd

# df = pd.read_csv('data.csv', index_col=0)
# df.plot(grid=True, title='t-N figure').get_figure().savefig("../../img/t-N.png", dpi=700)

# %%
df1=pd.read_csv('mpi4.csv',index_col=0)
df1
# Out:
#           mpi4
# N
# 64    0.004634
# 128   0.008701
# 192   0.018418
# 256   0.023337
# 320   0.042925
# 384   0.069406
# 448   0.113504
# 512   0.210005
# 576   0.326531
# 640   0.412540
# 704   0.586948
# 768   0.775189
# 832   1.011081
# 896   1.266200
# 960   1.642726
# 1024  1.884176

# %%
df2=pd.read_csv('mpi10.csv',index_col=0)
df2
# Out:
#          mpi10
# N
# 64    0.187470
# 128   0.213815
# 192   0.204990
# 256   0.230136
# 320   0.267843
# 384   0.326066
# 448   0.373722
# 512   0.500444
# 576   0.619807
# 640   0.778805
# 704   0.748804
# 768   1.032555
# 832   1.289692
# 896   1.460101
# 960   1.785434
# 1024  1.903159

# %%
df3=pd.read_csv('naive.csv',index_col=0)
df3
# Out:
#          naive
# N
# 64    0.001800
# 128   0.017032
# 192   0.024890
# 256   0.056232
# 320   0.101472
# 384   0.176030
# 448   0.273190
# 512   0.467586
# 576   0.578732
# 640   0.824071
# 704   1.062758
# 768   1.466353
# 832   1.741807
# 896   2.215411
# 960   2.674636
# 1024  3.705850

# %%
df1['mpi10']=df2['mpi10']
df1['naive']=df3['naive']
df1
# Out:
#           mpi4     mpi10     naive
# N
# 64    0.004634  0.187470  0.001800
# 128   0.008701  0.213815  0.017032
# 192   0.018418  0.204990  0.024890
# 256   0.023337  0.230136  0.056232
# 320   0.042925  0.267843  0.101472
# 384   0.069406  0.326066  0.176030
# 448   0.113504  0.373722  0.273190
# 512   0.210005  0.500444  0.467586
# 576   0.326531  0.619807  0.578732
# 640   0.412540  0.778805  0.824071
# 704   0.586948  0.748804  1.062758
# 768   0.775189  1.032555  1.466353
# 832   1.011081  1.289692  1.741807
# 896   1.266200  1.460101  2.215411
# 960   1.642726  1.785434  2.674636
# 1024  1.884176  1.903159  3.705850

# %%
df1.plot(grid=True, title='t-N figure').get_figure().savefig("t-N.png", dpi=700)
